# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('data/r2_test.csv')
data.head()
# Out:
#     r2_test  method
# 0  0.035396  RF/DFT
# 1 -0.110704  RF/DFT
# 2  0.462735  RF/DFT
# 3  0.335911  RF/DFT
# 4  0.184605  RF/DFT

# %%
fig = plt.figure(figsize=(4, 4))
sns.violinplot(x=data["method"], y=data["r2_test"], inner="box")
plt.show()
fig.savefig("result/violin_plot.pdf")
